# %%
# Imports 
import pandas as pd

# %% [markdown]
# Query used to get weekly data from [Stackoverflow Query](https://data.stackexchange.com/stackoverflow/query/edit/1205218)
#
# ```SQL
# SELECT Id, CreationDate, Title, Body, Tags, ViewCount, AnswerCount, CommentCount
# FROM Posts
# WHERE (CreationDate BETWEEN '2019-01-14' AND '2019-01-20') AND Tags IS NOT NULL
# ORDER BY CreationDate ASC
# ```

# %% [markdown]
# # Notebook Overview:
# - Combine weekly csv's into one csv for the year of 2019
# - The following are links to the zipped versions of the weekly data:
#     - [Weeks 1 - 20](https://drive.google.com/open?id=1uttbh17hfhnfMLqnajbw3yX7LC27yQFY)
#     - [Weeks 21-40](https://drive.google.com/open?id=1Isrpl4XX-Sv3CDmI2eNI26fX8Hu98mt4)
#     - [Weeks 41-52](https://drive.google.com/open?id=15FEnPmx_LaP9_xpxB3zz6BMqFDgTbVc6)
# - [Combined 2019 data (zipped):](https://drive.google.com/open?id=1ZQHpysA5m8aL3bbMEiUJLdHmVDhZmaBq)

# %%
week1 = pd.read_csv('../data/individual_weekly/week1.csv')
week2 = pd.read_csv('../data/individual_weekly/week2.csv')
week3 = pd.read_csv('../data/individual_weekly/week3.csv')
week4 = pd.read_csv('../data/individual_weekly/week4.csv')
week5 = pd.read_csv('../data/individual_weekly/week5.csv')
week6 = pd.read_csv('../data/individual_weekly/week6.csv')
week7 = pd.read_csv('../data/individual_weekly/week7.csv')
week8 = pd.read_csv('../data/individual_weekly/week8.csv')
week9 = pd.read_csv('../data/individual_weekly/week9.csv')
week10 = pd.read_csv('../data/individual_weekly/week10.csv')

week1_10_list = [week1, week2, week3, week4, week5, week6, week7, week8, week9, week10 ]

week1_10_df = pd.concat(week1_10_list)

# %%
week1_10_df.tail()
# Out:
#              Id         CreationDate  \
# 40402  55083177  2019-03-09 23:59:03
# 40403  55083178  2019-03-09 23:59:05
# 40404  55083182  2019-03-09 23:59:32
# 40405  55083183  2019-03-09 23:59:33
# 40406  55083185  2019-03-09 23:59:55
#
#                                                    Title  \
# 40402  dplyr/tidyr: Spread and Get Unique Values of A...
# 40403  PostgreSQL: How do I get data from table `A` f...
# 40404        ImportError: cannot import name 'UserModel'
# 40405      How to change pop-up position in PickaDate.js
# 40406  How to serve a django server which running on ...
#
#                                                     Body  \
# 40402  <p>Suppose I have the following data frame:</p...
# 40403  <p>I want to fetch all parents that have kids ...
# 40404  <p>HELP, I have this <code>appp.py</code> file...
# 40405  <p>I want to know how to change to position of...
# 40406  <p>I am running a Django server which I am usi...
#
# ...

# %%
# Is there a way to create a function to upload and all dataframes and concat them together?
# def weekly_csv():
#     i = 1 
#     weekly_list = []
#     for i in range(53):
#         week_i = pd.read_csv('week(i)')
        
    
#         weekly_list.append()
#         i += 1 
    
#     final_csv = pd.concat(weekly_list)
#     return final_csv

# %%
week11 = pd.read_csv('../data/individual_weekly/week11.csv')
week12 = pd.read_csv('../data/individual_weekly/week12.csv')
week13 = pd.read_csv('../data/individual_weekly/week13.csv')
week14 = pd.read_csv('../data/individual_weekly/week14.csv')
week15 = pd.read_csv('../data/individual_weekly/week15.csv')
week16 = pd.read_csv('../data/individual_weekly/week16.csv')
week17 = pd.read_csv('../data/individual_weekly/week17.csv')
week18 = pd.read_csv('../data/individual_weekly/week18.csv')
week19 = pd.read_csv('../data/individual_weekly/week19.csv')
week20 = pd.read_csv('../data/individual_weekly/week20.csv')

week11_20_list = [week11, week12, week13, week14, week15, week16, week17, week18, week19, week20 ]

week11_20_df = pd.concat(week11_20_list)

week11_20_df.head()
# Out:
#          Id         CreationDate  \
# 0  55093643  2019-03-11 00:00:01
# 1  55093646  2019-03-11 00:00:46
# 2  55093649  2019-03-11 00:01:09
# 3  55093651  2019-03-11 00:01:29
# 4  55093654  2019-03-11 00:02:17
#
#                                                Title  \
# 0  How to check if a command line argument is a d...
# 1  python - Cloud Firestore - append data to subc...
# 2  Changing the contents of an array in a recursi...
# 3                         Loop only takes last value
# 4  PyQt Access to LineEdit Function in Widget Fun...
#
#                                                 Body  \
# 0  <p>Hi guys I am a beginner in Java and I have ...
# 1  <p>Is it possible to append data to a subcolle...
# 2  <p>I am having trouble understanding something...
# 3  <p>I have a dataFrame with country-specific po...
# 4  <p>I made a Widget Object and created a LineEd...
#
#                                    Tags  ViewCount  AnswerCount  CommentCount
# ...

# %%
week21 = pd.read_csv('../data/individual_weekly/week21.csv')
week22 = pd.read_csv('../data/individual_weekly/week22.csv')
week23 = pd.read_csv('../data/individual_weekly/week23.csv')
week24 = pd.read_csv('../data/individual_weekly/week24.csv')
week25 = pd.read_csv('../data/individual_weekly/week25.csv')
week26 = pd.read_csv('../data/individual_weekly/week26.csv')
week27 = pd.read_csv('../data/individual_weekly/week27.csv')
week28 = pd.read_csv('../data/individual_weekly/week28.csv')
week29 = pd.read_csv('../data/individual_weekly/week29.csv')
week30 = pd.read_csv('../data/individual_weekly/week30.csv')

week21_30_list = [week21, week22, week23, week24, week25, week26, week27, week28, week29, week30 ]

week21_30_df = pd.concat(week21_30_list)

# %%
week21_30_df.tail()
# Out:
#              Id         CreationDate  \
# 37930  57236928  2019-07-27 23:58:18
# 37931  57236931  2019-07-27 23:59:14
# 37932  57236932  2019-07-27 23:59:24
# 37933  57236934  2019-07-27 23:59:32
# 37934  57236936  2019-07-27 23:59:52
#
#                                                    Title  \
# 37930      Call a function with a part of a larger array
# 37931  How to get the values from a multiselect field...
# 37932  Cross origin requests are only supported for p...
# 37933   Parse integer from a "td" tag with beautifulsoup
# 37934  How do I hook up the code to change Drupal mod...
#
#                                                     Body  \
# 37930  <p>I'm refactoring some code and have decided ...
# 37931  <p>I have a field in a content type which is a...
# 37932  <p>I can't send info to php, it gets blocked.<...
# 37933  <p>I read many articles about beautifulsoup bu...
# 37934  <p>Drupal does not allow me to delete extensio...
#
# ...

# %%
week31 = pd.read_csv('../data/individual_weekly/week31.csv')
week32 = pd.read_csv('../data/individual_weekly/week32.csv')
week33 = pd.read_csv('../data/individual_weekly/week33.csv')
week34 = pd.read_csv('../data/individual_weekly/week34.csv')
week35 = pd.read_csv('../data/individual_weekly/week35.csv')
week36 = pd.read_csv('../data/individual_weekly/week36.csv')
week37 = pd.read_csv('../data/individual_weekly/week37.csv')
week38 = pd.read_csv('../data/individual_weekly/week38.csv')
week39 = pd.read_csv('../data/individual_weekly/week39.csv')
week40 = pd.read_csv('../data/individual_weekly/week40.csv')

week31_40_list = [week31, week32, week33, week34, week35, week36, week37, week38, week39, week40 ]

week31_40_df = pd.concat(week31_40_list)
week31_40_df.head()
# Out:
#          Id         CreationDate  \
# 0  57245838  2019-07-29 00:00:07
# 1  57245840  2019-07-29 00:00:34
# 2  57245841  2019-07-29 00:00:54
# 3  57245847  2019-07-29 00:02:33
# 4  57245848  2019-07-29 00:03:20
#
#                                                Title  \
# 0  How do I create a user input loop that sums th...
# 1  AJAX won't load new page content without page ...
# 2  TypeError: Cannot call method "getSheetByName"...
# 3                           TypeError in graphics.py
# 4       iPython Notebook/Jupyter not actually saving
#
#                                                 Body  \
# 0  <p>Basically I'm trying to create a for loop i...
# 1  <p>I executed an AJAX request to load content ...
# 2  <p>I have this script I hacked together to run...
# 3  <p>I'm trying to make a rudimentary cookie cli...
# 4  <p>Saving my work does actually nothing.</p>\n...
#
#                                                 Tags  ViewCount  AnswerCount  \
# ...

# %%
week41 = pd.read_csv('../data/individual_weekly/week41.csv')
week42 = pd.read_csv('../data/individual_weekly/week42.csv')
week43 = pd.read_csv('../data/individual_weekly/week43.csv')
week44 = pd.read_csv('../data/individual_weekly/week44.csv')
week45 = pd.read_csv('../data/individual_weekly/week45.csv')
week46 = pd.read_csv('../data/individual_weekly/week46.csv')
week47 = pd.read_csv('../data/individual_weekly/week47.csv')
week48 = pd.read_csv('../data/individual_weekly/week48.csv')
week49 = pd.read_csv('../data/individual_weekly/week49.csv')
week50 = pd.read_csv('../data/individual_weekly/week50.csv')
week51 = pd.read_csv('../data/individual_weekly/week51.csv')
week52 = pd.read_csv('../data/individual_weekly/week52.csv')

week41_52_list = [week41, week42, week43, week44, week45, week46, week47, week48, week49, week50, week51, week52]

week41_52_df = pd.concat(week41_52_list)
week41_52_df.head()
# Out:
#          Id         CreationDate  \
# 0  58262165  2019-10-07 00:01:04
# 1  58262166  2019-10-07 00:01:05
# 2  58262167  2019-10-07 00:01:23
# 3  58262171  2019-10-07 00:03:01
# 4  58262172  2019-10-07 00:03:03
#
#                                                Title  \
# 0           Downloaded PDF file but cannot locate it
# 1          Does google colab permanently change file
# 2                       Analyzing multiple sequences
# 3  How to convert dates from different centuries ...
# 4   Pan events in ios 13 aren't behaving as expected
#
#                                                 Body  \
# 0  <p>I used swift code to download a PDF file. I...
# 1  <p>I am doing some data pre-processing on Goog...
# 2  <p>after working on some basic classification ...
# 3  <p>I am trying to use the function <code>parse...
# 4  <p>I'm trying to fix a bug that appears only o...
#
#                                                 Tags  ViewCount  AnswerCount  \
# ...

# %%
combined_list = [week1_10_df, week11_20_df, week21_30_df, week31_40_df,week41_52_df]

# %%
combined_df = pd.concat(combined_list)

# %%
combined_df.to_csv('weekly_combined2019.csv', index=False)
